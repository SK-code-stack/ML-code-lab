# %% [markdown]
# # Steps
# 1. Create new conda environment and name it 'python_ml'
# 	to create conda env --> conda create -n python_ml
# 	to activate this environment --> conda activate python_ml
# 2. Install the following packages:
#     1.	Python
# 	2.  Pandas
# 	3.  Numpy
# 	4.  Matplotlib
# 	5.  Seaborn
# 	6.  Scipy
# 	7.  Scikit – learn
# 	8.  Jupyter
# 	9.  Openpyxl
# 	10. Plotly
#
# 	pip install pandas numpy matplotlib seaborn scipy Scikit-learn jupyter openpyxl plotly

# %%
import pandas as pd
print("hi")
# Out:
# hi
